# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data=pd.read_csv('../artifacts/IMDB Dataset.csv')

# %%
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ## Data Preprocessing

# %%
data.shape
# Out:
# (50000, 2)

# %%
data.duplicated().sum()
# Out:
# np.int64(418)

# %%
data.duplicated(subset='review').sum()
# Out:
# np.int64(418)

# %%
data[data.duplicated(subset='review', keep=False)].head(10)
# Out:
#                                                 review sentiment
# 42   Of all the films I have seen, this one, The Ra...  negative
# 84   We brought this film as a joke for a friend, a...  negative
# 140  Before I begin, let me get something off my ch...  negative
# 219  Ed Wood rides again. The fact that this movie ...  negative
# 245  I have seen this film at least 100 times and I...  positive
# 480  From director Barbet Schroder (Reversal of For...  negative
# 513  The story and the show were good, but it was r...  negative
# 636  I rented this thinking it would be pretty good...  negative
# 638  This movie has everything typical horror movie...  positive
# 701  I Enjoyed Watching This Well Acted Movie Very ...  positive

# %%
#remove duplicate
data = data.drop_duplicates(subset='review')

# %%
data = data.reset_index(drop=True)

# %%
data.duplicated(subset='review').sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %% [markdown]
# ## Text Preprocessing

# %%
import re
import string

# %% [markdown]
# #### convert uppercase to lowercase

# %%
data["review"]=data["review"].apply(lambda x:" ".join(x.lower() for x in x.split()))

# %%
data["review"].head()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production. <br /><br />the...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically there's a family where a little boy ...
# 4    petter mattei's "love in the time of money" is...
# Name: review, dtype: str

# %% [markdown]
# #### Remove Links

# %%
data["review"]=data["review"].apply(lambda x: " ".join(re.sub(r'^https?:\/\/.*[\r\n]*','',x,flags=re.MULTILINE) for x in x.split()))

# %%
data["review"].head()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production. <br /><br />the...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically there's a family where a little boy ...
# 4    petter mattei's "love in the time of money" is...
# Name: review, dtype: str

# %% [markdown]
# #### Remove Punctuations

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text=text.replace(punctuation,'')
    return text

data["review"]=data["review"].apply(remove_punctuations)

# %%
data["review"].head()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production br br the filmin...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically theres a family where a little boy j...
# 4    petter matteis love in the time of money is a ...
# Name: review, dtype: str

# %% [markdown]
# #### Remove numbers

# %%
data["review"]=data["review"].str.replace('\d+', '',regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Chirath Rasandun\AppData\Local\Temp\ipykernel_7124\782582486.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data["review"]=data["review"].str.replace('\d+', '',regex=True)

# %%
data["review"].tail()
# Out:
# 49577    i thought this movie did a down right good job...
# 49578    bad plot bad dialogue bad acting idiotic direc...
# 49579    i am a catholic taught in parochial elementary...
# 49580    im going to have to disagree with the previous...
# 49581    no one expects the star trek movies to be high...
# Name: review, dtype: str

# %% [markdown]
# #### Remove stopwords

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (3.9.3)
# Requirement already satisfied: click in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

# %%
nltk.download('stopwords',download_dir='../static/model')
# Out:
# [nltk_data] Downloading package stopwords to ../static/model...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
with open('../static/model/corpora/stopwords/english','r') as file:
    sw=file.read().splitlines()

# %%
sw
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
data['review']=data['review'].apply(lambda x:" ".join(x for x in x.split() if x not in sw))

# %%
data["review"].head()
# Out:
# 0    one reviewers mentioned watching oz episode yo...
# 1    wonderful little production br br filming tech...
# 2    thought wonderful way spend time hot summer we...
# 3    basically theres family little boy jake thinks...
# 4    petter matteis love time money visually stunni...
# Name: review, dtype: str

# %% [markdown]
# #### Remove Stemming

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()

# %%
data['review']=data['review'].apply(lambda x:" ".join(ps.stem(x) for x in x.split()))

# %%
data['review'].head()
# Out:
# 0    one review mention watch oz episod youll hook ...
# 1    wonder littl product br br film techniqu unass...
# 2    thought wonder way spend time hot summer weeke...
# 3    basic there famili littl boy jake think there ...
# 4    petter mattei love time money visual stun film...
# Name: review, dtype: str

# %% [markdown]
# #### Building Vocabulary

# %%
from collections import Counter
vocab=Counter()

# %%
vocab
# Out:
# Counter()

# %%
for sentence in data['review']:
    vocab.update(sentence.split())

# %%
len(vocab)
# Out:
# 138642

# %%
data.shape
# Out:
# (49582, 2)

# %%
tokens=[key for key in vocab if vocab[key] >20]

# %%
tokens
# Out:
# ['one',
#  'review',
#  'mention',
#  'watch',
#  'oz',
#  'episod',
#  'youll',
#  'hook',
#  'right',
#  'exactli',
#  'happen',
#  'mebr',
#  'br',
#  'first',
#  'thing',
#  'struck',
#  'brutal',
#  'unflinch',
#  'scene',
#  'violenc',
#  'set',
#  'word',
#  'go',
#  'trust',
#  'show',
#  'faint',
#  'heart',
#  'timid',
#  'pull',
#  'punch',
#  'regard',
#  'drug',
#  'sex',
#  'hardcor',
#  'classic',
#  'use',
#  'call',
#  'nicknam',
#  'given',
#  'oswald',
#  'maximum',
#  'secur',
#  'state',
#  'focus',
#  'mainli',
#  'citi',
#  'experiment',
#  'section',
#  'prison',
#  'cell',
#  'glass',
#  'front',
#  'face',
#  'privaci',
#  'high',
#  'agenda',
#  'em',
#  'home',
#  'muslim',
#  'gangsta',
#  'latino',
#  'christian',
#  'italian',
#  'irish',
#  'moreso',
#  'death',
#  'stare',
#  'dodgi',
#  'deal',
#  'shadi',
#  'agreement',
#  'never',
#  'far',
#  'awaybr',
#  'would',
#  'say',
#  'main',
#  'appeal',
#  'due',
#  'fact',
#  'goe',
#  'wouldnt',
#  'dare',
#  'forget',
#  'pretti',
#  'pictur',
#  'paint',
#  'mainstream',
#  'audienc',
#  'charm',
#  'doesnt',
#  'mess',
#  'around',
#  'ever',
#  'saw',
#  'nasti',
#  'surreal',
#  'couldnt',
#  'readi',
#  'develop',
#  'tast',
#  'got',
#  'accustom',
#  'level',
#  'graphic',
#  'injustic',
#  'crook',
#  'guard',
#  'wholl',
#  'sold',
#  'inmat',
#  'kill',
#  'order',
#  'get',
#  'away',
#  'well',
#  'manner',
#  'middl',
#  'class',
#  'turn',
#  'bitch',
#  'lack',
#  'street',
#  'skill',
#  'experi',
#  'may',
#  'becom',
#  'comfort',
#  'uncomfort',
#  'touch',
#  'darker',
#  'side',
#  'wonder',
#  'littl',
#  'product',
#  'film',
#  'techniqu',
#  'unassum',
#  'fashion',
#  'give',
#  'sometim',
#  'discomfort',
#  'sens',
#  'realism',
#  'entir',
#  'piec',
#  'actor',
#  'extrem',
#  'chosen',
#  'michael',
#  'sheen',
#  'voic',
#  'pat',
#  'truli',
#  'see',
#  'seamless',
#  'edit',
#  'guid',
#  'refer',
#  'william',
#  'diari',
#  'entri',
#  'worth',
#  'written',
#  'perform',
#  'master',
#  'great',
#  'comedi',
#  'life',
#  'realli',
#  'come',
#  'fantasi',
#  'rather',
#  'tradit',
#  'dream',
#  'remain',
#  'solid',
#  'disappear',
#  'play',
#  'knowledg',
#  'particularli',
#  'concern',
#  'flat',
#  'decor',
#  'everi',
#  'surfac',
#  'terribl',
#  'done',
#  'thought',
#  'way',
#  'spend',
#  'time',
#  'hot',
#  'summer',
#  'weekend',
#  'sit',
#  'air',
#  'condit',
#  'theater',
#  'lightheart',
#  'plot',
#  'simplist',
#  'dialogu',
#  'witti',
#  'charact',
#  'likabl',
#  'even',
#  'bread',
#  'suspect',
#  'serial',
#  'killer',
#  'disappoint',
#  'realiz',
#  'match',
#  'point',
#  'risk',
#  'addict',
#  'proof',
#  'woodi',
#  'allen',
#  'still',
#  'fulli',
#  'control',
#  'style',
#  'mani',
#  'us',
#  'grown',
#  'lovebr',
#  'id',
#  'laugh',
#  'year',
#  'decad',
#  'ive',
#  'impress',
#  'scarlet',
#  'manag',
#  'tone',
#  'sexi',
#  'imag',
#  'jump',
#  'averag',
#  'spirit',
#  'young',
#  'womanbr',
#  'crown',
#  'jewel',
#  'career',
#  'devil',
#  'wear',
#  'interest',
#  'superman',
#  'friend',
#  'basic',
#  'there',
#  'famili',
#  'boy',
#  'jake',
#  'think',
#  'zombi',
#  'closet',
#  'parent',
#  'fight',
#  'timebr',
#  'movi',
#  'slower',
#  'soap',
#  'opera',
#  'suddenli',
#  'decid',
#  'rambo',
#  'ok',
#  'your',
#  'make',
#  'must',
#  'thriller',
#  'drama',
#  'watchabl',
#  'divorc',
#  'argu',
#  'like',
#  'real',
#  'total',
#  'ruin',
#  'expect',
#  'boogeyman',
#  'similar',
#  'instead',
#  'meaningless',
#  'descent',
#  'dialog',
#  'shot',
#  'ignor',
#  'mattei',
#  'love',
#  'money',
#  'visual',
#  'stun',
#  'mr',
#  'offer',
#  'vivid',
#  'portrait',
#  'human',
#  'relat',
#  'seem',
#  'tell',
#  'power',
#  'success',
#  'peopl',
#  'differ',
#  'situat',
#  'encount',
#  'variat',
#  'arthur',
#  'theme',
#  'director',
#  'transfer',
#  'action',
#  'present',
#  'new',
#  'york',
#  'meet',
#  'connect',
#  'anoth',
#  'next',
#  'person',
#  'know',
#  'previou',
#  'contact',
#  'stylishli',
#  'sophist',
#  'luxuri',
#  'look',
#  'taken',
#  'live',
#  'world',
#  'soul',
#  'stage',
#  'loneli',
#  'inhabit',
#  'big',
#  'best',
#  'place',
#  'find',
#  'sincer',
#  'fulfil',
#  'discern',
#  'case',
#  'act',
#  'good',
#  'direct',
#  'steve',
#  'buscemi',
#  'rosario',
#  'dawson',
#  'carol',
#  'kane',
#  'imperioli',
#  'adrian',
#  'rest',
#  'talent',
#  'cast',
#  'alivebr',
#  'wish',
#  'luck',
#  'await',
#  'anxious',
#  'work',
#  'probabl',
#  'alltim',
#  'favorit',
#  'stori',
#  'selfless',
#  'sacrific',
#  'dedic',
#  'nobl',
#  'caus',
#  'preachi',
#  'bore',
#  'old',
#  'despit',
#  'seen',
#  'last',
#  'paul',
#  'luka',
#  'bring',
#  'tear',
#  'eye',
#  'bett',
#  'davi',
#  'sympathet',
#  'role',
#  'delight',
#  'kid',
#  'grandma',
#  'midget',
#  'children',
#  'fun',
#  'mother',
#  'slow',
#  'awaken',
#  'what',
#  'roof',
#  'believ',
#  'startl',
#  'dozen',
#  'thumb',
#  'theyd',
#  'sure',
#  'resurrect',
#  'date',
#  'seri',
#  'tech',
#  'today',
#  'back',
#  'excit',
#  'mei',
#  'grew',
#  'black',
#  'white',
#  'tv',
#  'hero',
#  'vote',
#  'comeback',
#  'sea',
#  'need',
#  'chang',
#  'pace',
#  'water',
#  'thank',
#  'outlet',
#  'view',
#  'viewpoint',
#  'ole',
#  'wanna',
#  'nice',
#  'read',
#  'plu',
#  'rhyme',
#  'line',
#  'let',
#  'leav',
#  'doubt',
#  'amaz',
#  'fresh',
#  'innov',
#  'idea',
#  'brilliant',
#  'drop',
#  'funni',
#  'anymor',
#  'continu',
#  'declin',
#  'complet',
#  'wast',
#  'todaybr',
#  'disgrac',
#  'fallen',
#  'write',
#  'pain',
#  'bad',
#  'almost',
#  'mildli',
#  'entertain',
#  'respit',
#  'hard',
#  'creator',
#  'origin',
#  'also',
#  'chose',
#  'band',
#  'hack',
#  'follow',
#  'recogn',
#  'brillianc',
#  'fit',
#  'replac',
#  'mediocr',
#  'felt',
#  'star',
#  'respect',
#  'made',
#  'huge',
#  'aw',
#  'cant',
#  'encourag',
#  'posit',
#  'comment',
#  'forward',
#  'mistak',
#  'worst',
#  'storylin',
#  'soundtrack',
#  'song',
#  'lame',
#  'countri',
#  'tune',
#  'less',
#  'four',
#  'cheap',
#  'rare',
#  'happi',
#  'end',
#  'credit',
#  'prevent',
#  'score',
#  'harvey',
#  'keitel',
#  'least',
#  'bit',
#  'effort',
#  'obsess',
#  'gut',
#  'wrench',
#  'laughter',
#  'hell',
#  'mom',
#  'itbr',
#  'camp',
#  'phil',
#  'alien',
#  'quirki',
#  'humour',
#  'base',
#  'odd',
#  'everyth',
#  'actual',
#  'progress',
#  'didnt',
#  'joke',
#  'anymorebr',
#  'low',
#  'budget',
#  'that',
#  'problem',
#  'eventu',
#  'lost',
#  'interestbr',
#  'imagin',
#  'stoner',
#  'current',
#  'someth',
#  'better',
#  'tri',
#  'brother',
#  'planet',
#  'came',
#  'recal',
#  'scariest',
#  'bird',
#  'eat',
#  'men',
#  'dangl',
#  'helplessli',
#  'parachut',
#  'horror',
#  'horrorbr',
#  'cheesi',
#  'b',
#  'saturday',
#  'afternoon',
#  'tire',
#  'formula',
#  'monster',
#  'type',
#  'usual',
#  'includ',
#  'beauti',
#  'woman',
#  'might',
#  'daughter',
#  'professor',
#  'resolut',
#  'die',
#  'care',
#  'much',
#  'romant',
#  'angl',
#  'predict',
#  'unintent',
#  'humorbr',
#  'later',
#  'psycho',
#  'janet',
#  'leigh',
#  'bump',
#  'earli',
#  'sat',
#  'took',
#  'notic',
#  'sinc',
#  'screenwrit',
#  'scari',
#  'possibl',
#  'wellworn',
#  'rule',
#  'im',
#  'fan',
#  'boll',
#  'enjoy',
#  'postal',
#  'mayb',
#  'appar',
#  'bought',
#  'cri',
#  'long',
#  'ago',
#  'game',
#  'infiltr',
#  'secret',
#  'research',
#  'lab',
#  'locat',
#  'tropic',
#  'island',
#  'warn',
#  'scheme',
#  'togeth',
#  'along',
#  'legion',
#  'feel',
#  'invit',
#  'three',
#  'player',
#  'name',
#  'til',
#  'udo',
#  'kier',
#  'self',
#  'biz',
#  'tale',
#  'jack',
#  'carver',
#  'ye',
#  'german',
#  'hail',
#  'dude',
#  'howev',
#  'badass',
#  'complain',
#  'he',
#  'stay',
#  'true',
#  'whole',
#  'perspect',
#  'dont',
#  'kick',
#  'beyond',
#  'dement',
#  'evil',
#  'mad',
#  'scientist',
#  'dr',
#  'remind',
#  'spoiler',
#  'vancouv',
#  'reason',
#  'palm',
#  'tree',
#  'rich',
#  'havent',
#  'gone',
#  'start',
#  'cannot',
#  'shenanigan',
#  'deliv',
#  'mean',
#  'impli',
#  'area',
#  'boat',
#  'squad',
#  'enter',
#  'reek',
#  'poop',
#  'simpleton',
#  'take',
#  'ahead',
#  'btw',
#  'annoy',
#  'sidekick',
#  'shoot',
#  'minut',
#  'screen',
#  'shakespear',
#  'lostbr',
#  'appreci',
#  'mass',
#  'goodbr',
#  'scottish',
#  'certain',
#  'rev',
#  'henc',
#  'victorian',
#  'erabr',
#  'improv',
#  'ten',
#  'text',
#  'english',
#  'composit',
#  'fort',
#  'keep',
#  'cut',
#  'fantast',
#  'famou',
#  'georg',
#  'clooney',
#  'roll',
#  'man',
#  'constant',
#  'sorrow',
#  'everybodi',
#  'greet',
#  'bart',
#  'kind',
#  'drawn',
#  'erot',
#  'amateurish',
#  'unbeliev',
#  'sort',
#  'school',
#  'project',
#  'rosanna',
#  'arquett',
#  'stock',
#  'bizarr',
#  'suppos',
#  'midwest',
#  'town',
#  'involv',
#  'lesson',
#  'learn',
#  'insight',
#  'stilt',
#  'quit',
#  'ridicul',
#  'lot',
#  'skin',
#  'intrigu',
#  'videotap',
#  'bisexu',
#  'relationship',
#  'nowher',
#  'heterosexu',
#  'absurd',
#  'danc',
#  'stereotyp',
#  'pass',
#  'million',
#  'mile',
#  'could',
#  'spent',
#  'starv',
#  'aid',
#  'africa',
#  'simpli',
#  'remad',
#  'fail',
#  'captur',
#  'flavor',
#  'terror',
#  'titl',
#  'liam',
#  'neeson',
#  'excel',
#  'alway',
#  'hold',
#  'except',
#  'owen',
#  'wilson',
#  'luke',
#  'major',
#  'fault',
#  'version',
#  'stray',
#  'shirley',
#  'jackson',
#  'attempt',
#  'grandios',
#  'thrill',
#  'earlier',
#  'trade',
#  'special',
#  'effect',
#  'friction',
#  'older',
#  'top',
#  'horribl',
#  'wasnt',
#  'chanc',
#  'busi',
#  'run',
#  'sword',
#  'emot',
#  'attach',
#  'machin',
#  'want',
#  'destroy',
#  'blatantli',
#  'stolen',
#  'lotr',
#  'war',
#  'matrix',
#  'ghost',
#  'final',
#  'yoda',
#  'vader',
#  'spider',
#  'begin',
#  'frodo',
#  'attack',
#  'return',
#  'king',
#  'elijah',
#  'wood',
#  'victim',
#  'hypnot',
#  'sting',
#  'wrap',
#  'vs',
#  'exampl',
#  'someon',
#  'nazi',
#  'juvenil',
#  'rush',
#  'conclus',
#  'adult',
#  'either',
#  'save',
#  'rememb',
#  'filmit',
#  'cinema',
#  'dark',
#  'nervou',
#  'dad',
#  'sister',
#  'england',
#  'tiger',
#  'snow',
#  'appear',
#  'grizzli',
#  'adam',
#  'dan',
#  'anyon',
#  'dvd',
#  'etc',
#  'pleas',
#  'club',
#  'shame',
#  'nearest',
#  'hear',
#  'other',
#  'stinker',
#  'nomin',
#  'golden',
#  'globe',
#  'theyv',
#  'femal',
#  'renaiss',
#  'painter',
#  'mangl',
#  'recognit',
#  'complaint',
#  'liberti',
#  'perfectli',
#  'fine',
#  'account',
#  'artist',
#  'script',
#  'werent',
#  'enough',
#  'nake',
#  'factual',
#  'cap',
#  'summari',
#  'coupl',
#  'hour',
#  'favor',
#  'breviti',
#  'sequel',
#  'surpris',
#  'cash',
#  'wrong',
#  'guy',
#  'concept',
#  'cliffhang',
#  'mountain',
#  'rescu',
#  'sli',
#  'stop',
#  'stallon',
#  'careerbr',
#  'nitpick',
#  'especi',
#  'expert',
#  'climb',
#  'aviat',
#  'facial',
#  'express',
#  'full',
#  'excus',
#  'dismiss',
#  'overblown',
#  'pile',
#  'junk',
#  'hors',
#  'nonsens',
#  'lovabl',
#  'undeni',
#  'romp',
#  'plenti',
#  'laughsbr',
#  'youv',
#  'john',
#  'lithgow',
#  'tick',
#  'box',
#  'baddi',
#  'perman',
#  'harass',
#  'hapless',
#  'agent',
#  'rex',
#  'henri',
#  'rooker',
#  'noteworthi',
#  'cringeworthi',
#  'hal',
#  'insist',
#  'constantli',
#  'shriek',
#  'disbelief',
#  'captor',
#  'hurt',
#  'anybodi',
#  'whilst',
#  'ralph',
#  'wait',
#  'frank',
#  'grin',
#  'girl',
#  'plummet',
#  'deathbr',
#  'former',
#  'london',
#  'burn',
#  'craig',
#  'brit',
#  'footbal',
#  'help',
#  'judgement',
#  'lower',
#  'volum',
#  'helicopt',
#  'misfortun',
#  'bmovi',
#  'shouldnt',
#  'aspect',
#  'paperthin',
#  'sequenc',
#  'fake',
#  'pack',
#  'crappi',
#  'onelin',
#  'amus',
#  'bitbr',
#  'gear',
#  'toward',
#  'women',
#  'utterli',
#  'unattract',
#  'wrinkl',
#  'weird',
#  'costum',
#  'miserablybr',
#  'absolut',
#  'hr',
#  'wont',
#  'regret',
#  'carri',
#  'shoulder',
#  'although',
#  'isnt',
#  'anyth',
#  'music',
#  'grow',
#  'heard',
#  'straight',
#  'anim',
#  'matter',
#  'speed',
#  'racer',
#  'sever',
#  'theyr',
#  'hilari',
#  'c',
#  'godzilla',
#  'lotbr',
#  'move',
#  'fx',
#  'sudden',
#  'boom',
#  ...]

# %%
len(tokens)
# Out:
# 14378

# %%
def save_vocabulary(lines, filename):
    data='\n'.join(lines)
    file=open(filename,'w',encoding="utf-8")
    file.write(data)
    file.close()

save_vocabulary(tokens,'../static/model/vocabulary.txt')

# %% [markdown]
# #### Split data set

# %%
X=data['review']
y=data['sentiment']

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Chirath Rasandun\Desktop\AI-ML-Project\env\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (39665,)

# %%
X_test.shape
# Out:
# (9917,)

# %%
X_train
# Out:
# 33219    oh boy film like realli bother movi suppos clo...
# 42095    thought movi cleverli written well act movi gr...
# 35023    best comedi period underr clever witti humor g...
# 22131    im fan origin minut remak start think go good ...
# 20425    rural famili dramawith perhap nod ordinari peo...
#                                ...
# 11364    even though tri avoid german film recent posit...
# 36017    decoy one independ product made obviou newcom ...
# 4071     though seri ran season stay year far time favo...
# 8950     easili one worst movi ever seen much hous goe ...
# 29533    film sat tivo week watch dread selfindulg yupp...
# Name: review, Length: 39665, dtype: str

# %% [markdown]
# #### TF-IDF Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(
    vocabulary=tokens,           # Use your pre-built vocabulary
    lowercase=False,              # Already lowercased
    norm='l2',                    # L2 normalization (default)
    use_idf=True,                 # Use inverse document frequency
    smooth_idf=True,               # Smooth idf weights
    sublinear_tf=False             # Do not use sublinear tf scaling (1+log(tf))
)

# %%
vectorized_x_train = tfidf_vectorizer.fit_transform(X_train).toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 vectorized_x_train = tfidf_vectorizer.fit_transform(X_train).toarray()
#
# File ~\Desktop\AI-ML-Project\env\Lib\site-packages\scipy\sparse\_compressed.py:1005, in _cs_matrix.toarray(self, order, out)
#    1003 if out is None and order is None:
#    1004     order = self._swap('cf')[0]
# -> 1005 out = self._process_toarray_args(order, out)
#    1006 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1007     raise ValueError('Output array must be C or F contiguous')
#
# File ~\Desktop\AI-ML-Project\env\Lib\site-packages\scipy\sparse\_base.py:1523, in _spbase._process_toarray_args(self, order, out)
#    1521     return out
#    1522 else:
# -> 1523     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 4.25 GiB for an array with shape (39665, 14378) and data type float64

# %%
vectorized_x_train

# %%
vectorized_x_test = tfidf_vectorizer.transform(X_test).toarray()

# %%
print(f"Vectorized training shape: {vectorized_x_train.shape}")

# %%
print(f"Vectorized test shape: {vectorized_x_test.shape}")

# %%
#Check TF-IDF values for first sample
print(f"Sample TF-IDF vector (first 20 features):\n{vectorized_x_train[0][:20]}")

# %%
y_train.value_counts()

# %%
import matplotlib.pyplot as plt
plt.pie(np.array([y_train.value_counts()['positive'], y_train.value_counts()['negative']]), 
        labels=['Positive', 'Negative'])
plt.title('Original Class Distribution')
plt.show()

# %% [markdown]
# #### Model Training and Evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

lr_model= LogisticRegression(random_state=42)
lr_model.fit(vectorized_x_train,y_train)
y_pred=lr_model.predict(vectorized_x_test)

print(classification_report(y_test,y_pred))
print('Confusion matrix:\n',confusion_matrix(y_test,y_pred))
print('Accuracy for test data:',accuracy_score(y_test,y_pred)*100)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Define Logistic Regression model
lr_model = LogisticRegression()

# Hyperparameter distribution (same as your grid)
param_dist = {
    'C': [0.1, 1, 10],
    'solver': ['liblinear'],
    'max_iter': [100]
}

# Randomized Search
random_search = RandomizedSearchCV(
    lr_model,
    param_distributions=param_dist,
    n_iter=3,         # Number of parameter settings to sample
    cv=3,
    scoring='accuracy',
    n_jobs=1,         # Avoid memory issues with multiple cores
    verbose=1,
    random_state=42
)

# Train
random_search.fit(vectorized_x_train, y_train)

# Best parameters
print("Best Parameters:", random_search.best_params_)

# Best model
best_lr = random_search.best_estimator_

# Predictions
y_pred = best_lr.predict(vectorized_x_test)

# Evaluation
print(classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
print("Accuracy for test data:", accuracy_score(y_test, y_pred) * 100)

# %%
from sklearn.model_selection import GridSearchCV

# Hyperparameter grid
param_grid = {
    'C':[0.1,1,10],
    'solver':['liblinear'],
    'max_iter':[100]
}

# Grid Search
grid = GridSearchCV(
    lr_model,
    param_grid,
    cv=3,
    scoring='accuracy',
    n_jobs=1,
    verbose=1
)

# Train
grid.fit(vectorized_x_train, y_train)

# Best parameters
print("Best Parameters:", grid.best_params_)

# Best model
best_lr = grid.best_estimator_

# Predictions
y_pred = best_lr.predict(vectorized_x_test)

print(classification_report(y_test, y_pred))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
print("Accuracy for test data:", accuracy_score(y_test, y_pred) * 100)

# %% [markdown]
# #### Naive Bayes

# %%
mnb = MultinomialNB()
mnb.fit(vectorized_x_train, y_train)
y_pred=mnb.predict(vectorized_x_test)

print(classification_report(y_test,y_pred))
print('Confusion matrix:\n',confusion_matrix(y_test,y_pred))
print('Accuracy for test data:',accuracy_score(y_test,y_pred)*100)

# %% [markdown]
# #### Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(vectorized_x_train, y_train)

y_pred=dt.predict(vectorized_x_test)

print(classification_report(y_test,y_pred))
print('Confusion matrix:\n',confusion_matrix(y_test,y_pred))
print('Accuracy for test data:',accuracy_score(y_test,y_pred)*100)

# %% [markdown]
# #### RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(vectorized_x_train, y_train)
y_pred=rf.predict(vectorized_x_test)

print(classification_report(y_test,y_pred))
print('Confusion matrix:\n',confusion_matrix(y_test,y_pred))
print('Accuracy for test data:',accuracy_score(y_test,y_pred)*100)

# %%
import pickle

with open('../static/model/model.pickle','wb') as file:
    pickle.dump(lr_model,file)

# %%
from sklearn.ensemble import RandomForestClassifier
import joblib
joblib.dump(svm, "modelsenti.pkl")
